# %% [markdown]
# # Programação para Ciência de Dados
# # Aula 12 - Análise de Dados Multidimensionais
# # Prática Independente
#
# **Instruções:**
# - Este notebook contém exercícios para prática independente dos conceitos da Aula 12
# - Preencha apenas as células marcadas com `# SEU CODIGO AQUI`
# - Não modifique as células de teste
# - Execute todas as células em ordem

# %% [markdown]
# ## Setup
#
# Execute as células abaixo para importar as bibliotecas necessárias.

# %%
# === CONFIGURAÇÃO OTTER GRADER ===
# !pip install --upgrade pip --quiet
# !pip cache purge
# !pip install otter-grader --no-cache-dir -q
# !mkdir -p tests

import otter
grader = otter.Notebook()

print("✓ Otter Grader instalado!")
print("✓ Diretório de testes criado!")

# %%
# %%writefile tests/ex1a.py
OK_FORMAT = True

test = {
    "name": "ex1a",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'tensor_3d' in dir(), "Variável tensor_3d não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(tensor_3d, np.ndarray), "tensor_3d deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> import numpy as np
>>> assert tensor_3d.shape == (4, 5, 6), f"Shape incorreto: esperado (4, 5, 6), obtido {tensor_3d.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores no intervalo correto
>>> import numpy as np
>>> assert tensor_3d.min() >= 10, f"Valor mínimo deve ser >= 10, obtido {tensor_3d.min()}"
>>> assert tensor_3d.max() <= 50, f"Valor máximo deve ser <= 50, obtido {tensor_3d.max()}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: É array de inteiros
>>> import numpy as np
>>> assert tensor_3d.dtype in [np.int32, np.int64], "tensor_3d deve conter inteiros"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Seed foi usado corretamente
>>> import numpy as np
>>> np.random.seed(42)
>>> expected = np.random.randint(10, 51, size=(4, 5, 6))
>>> assert np.array_equal(tensor_3d, expected), "Valores incorretos. Certifique-se de usar np.random.seed(42) antes de gerar o tensor"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex1b.py
OK_FORMAT = True

test = {
    "name": "ex1b",
    "points": 2,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'camada_2' in dir(), "Variável camada_2 não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(camada_2, np.ndarray), "camada_2 deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert camada_2.shape == (5, 6), f"Shape incorreto: esperado (5, 6), obtido {camada_2.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> assert np.array_equal(camada_2, tensor_3d[1]), "camada_2 deve ser igual a tensor_3d[1]"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex1c.py
OK_FORMAT = True

test = {
    "name": "ex1c",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'media_axis0' in dir(), "Variável media_axis0 não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(media_axis0, np.ndarray), "media_axis0 deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert media_axis0.shape == (5, 6), f"Shape incorreto: esperado (5, 6), obtido {media_axis0.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> expected_mean = tensor_3d.mean(axis=0)
>>> assert np.allclose(media_axis0, expected_mean), "Valores incorretos. Use .mean(axis=0)"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Média global preservada
>>> import numpy as np
>>> assert np.isclose(media_axis0.mean(), tensor_3d.mean()), "A média global deve ser preservada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex2a.py
OK_FORMAT = True

test = {
    "name": "ex2a",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'intensidade_media' in dir(), "Variável intensidade_media não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(intensidade_media, np.ndarray), "intensidade_media deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert intensidade_media.shape == (1797,), f"Shape incorreto: esperado (1797,), obtido {intensidade_media.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> expected_intensidade = X.mean(axis=(1, 2))
>>> assert np.allclose(intensidade_media, expected_intensidade), "Valores incorretos. Use .mean(axis=(1, 2))"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Valores não-negativos
>>> assert intensidade_media.min() >= 0, "Intensidades não podem ser negativas"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Valores dentro do limite
>>> assert intensidade_media.max() <= 16, "Intensidades não podem exceder o máximo do dataset"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 7: Média global preservada
>>> import numpy as np
>>> assert np.isclose(intensidade_media.mean(), X.mean()), "A média global deve ser preservada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex2b.py
OK_FORMAT = True

test = {
    "name": "ex2b",
    "points": 4,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'imagens_medias' in dir(), "Variável imagens_medias não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(imagens_medias, np.ndarray), "imagens_medias deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert imagens_medias.shape == (10, 8, 8), f"Shape incorreto: esperado (10, 8, 8), obtido {imagens_medias.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos para cada dígito
>>> import numpy as np
>>> for digito in range(10):
...     expected = X[y == digito].mean(axis=0)
...     assert np.allclose(imagens_medias[digito], expected), f"Imagem média incorreta para dígito {digito}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Valores não-negativos
>>> assert imagens_medias.min() >= 0, "Valores não podem ser negativos"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Valores dentro do limite
>>> assert imagens_medias.max() <= 16, "Valores não podem exceder o máximo do dataset"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex2c.py
OK_FORMAT = True

test = {
    "name": "ex2c",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'X_normalizado' in dir(), "Variável X_normalizado não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(X_normalizado, np.ndarray), "X_normalizado deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape preservado
>>> assert X_normalizado.shape == X.shape, f"Shape incorreto: esperado {X.shape}, obtido {X_normalizado.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Mínimo é zero
>>> import numpy as np
>>> assert np.isclose(X_normalizado.min(), 0.0), f"Mínimo deve ser 0, obtido {X_normalizado.min()}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Máximo é um
>>> import numpy as np
>>> assert np.isclose(X_normalizado.max(), 1.0), f"Máximo deve ser 1, obtido {X_normalizado.max()}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Fórmula correta
>>> import numpy as np
>>> expected = (X - X.min()) / (X.max() - X.min())
>>> assert np.allclose(X_normalizado, expected), "Fórmula de normalização incorreta"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex3a.py
OK_FORMAT = True

test = {
    "name": "ex3a",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'vendas_por_produto' in dir(), "Variável vendas_por_produto não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(vendas_por_produto, np.ndarray), "vendas_por_produto deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert vendas_por_produto.shape == (5,), f"Shape incorreto: esperado (5,), obtido {vendas_por_produto.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> expected = vendas.sum(axis=(1, 2))
>>> assert np.array_equal(vendas_por_produto, expected), "Valores incorretos. Use .sum(axis=(1, 2))"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Soma total preservada
>>> assert vendas_por_produto.sum() == vendas.sum(), "A soma total deve ser preservada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex3b.py
OK_FORMAT = True

test = {
    "name": "ex3b",
    "points": 2,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'vendas_por_regiao' in dir(), "Variável vendas_por_regiao não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(vendas_por_regiao, np.ndarray), "vendas_por_regiao deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert vendas_por_regiao.shape == (3,), f"Shape incorreto: esperado (3,), obtido {vendas_por_regiao.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> expected = vendas.sum(axis=(0, 2))
>>> assert np.array_equal(vendas_por_regiao, expected), "Valores incorretos. Use .sum(axis=(0, 2))"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex3c.py
OK_FORMAT = True

test = {
    "name": "ex3c",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'vendas_por_mes' in dir(), "Variável vendas_por_mes não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(vendas_por_mes, np.ndarray), "vendas_por_mes deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert vendas_por_mes.shape == (12,), f"Shape incorreto: esperado (12,), obtido {vendas_por_mes.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos
>>> import numpy as np
>>> expected = vendas.sum(axis=(0, 1))
>>> assert np.array_equal(vendas_por_mes, expected), "Valores incorretos. Use .sum(axis=(0, 1))"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Soma total preservada
>>> assert vendas_por_mes.sum() == vendas.sum(), "A soma total deve ser preservada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex4a.py
OK_FORMAT = True

test = {
    "name": "ex4a",
    "points": 4,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável X_centrado existe
>>> assert 'X_centrado' in dir(), "Variável X_centrado não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(X_centrado, np.ndarray), "X_centrado deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape preservado
>>> assert X_centrado.shape == X.shape, f"Shape incorreto: esperado {X.shape}, obtido {X_centrado.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos com broadcasting
>>> import numpy as np
>>> medias_teste = X.mean(axis=(1, 2), keepdims=True)
>>> expected = X - medias_teste
>>> assert np.allclose(X_centrado, expected), "Valores incorretos. Use broadcasting com keepdims=True"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Cada imagem com média zero
>>> import numpy as np
>>> medias_por_imagem = X_centrado.mean(axis=(1, 2))
>>> assert np.allclose(medias_por_imagem, 0, atol=1e-10), "Cada imagem deve ter média próxima de zero"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Variável medias existe
>>> assert 'medias' in dir(), "Variável medias não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 7: Shape de medias correto
>>> assert medias.shape == (1797, 1, 1), f"Shape de medias deve ser (1797, 1, 1), obtido {medias.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex4b.py
OK_FORMAT = True

test = {
    "name": "ex4b",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'vendas_normalizadas' in dir(), "Variável vendas_normalizadas não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(vendas_normalizadas, np.ndarray), "vendas_normalizadas deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape preservado
>>> assert vendas_normalizadas.shape == vendas.shape, f"Shape incorreto: esperado {vendas.shape}, obtido {vendas_normalizadas.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Valores corretos com broadcasting
>>> import numpy as np
>>> medias_teste = vendas.mean(axis=(1, 2), keepdims=True)
>>> expected = vendas - medias_teste
>>> assert np.allclose(vendas_normalizadas, expected), "Valores incorretos. Use broadcasting com keepdims=True"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Cada produto com média zero
>>> import numpy as np
>>> for produto in range(5):
...     media_produto = vendas_normalizadas[produto].mean()
...     assert np.isclose(media_produto, 0, atol=1e-10), f"Produto {produto} deve ter média próxima de zero"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex5a.py
OK_FORMAT = True

test = {
    "name": "ex5a",
    "points": 3,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Máscara existe
>>> assert 'mascara_brilhantes' in dir(), "Variável mascara_brilhantes não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: Máscara é numpy array
>>> import numpy as np
>>> assert isinstance(mascara_brilhantes, np.ndarray), "mascara_brilhantes deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: Shape correto
>>> assert mascara_brilhantes.shape == (1797,), f"Shape incorreto: esperado (1797,), obtido {mascara_brilhantes.shape}"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Tipo booleano
>>> assert mascara_brilhantes.dtype == bool, "mascara_brilhantes deve ser booleana"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Máscara correta
>>> import numpy as np
>>> expected_mask = intensidade_media > 10
>>> assert np.array_equal(mascara_brilhantes, expected_mask), "Máscara incorreta. Use intensidade_media > 10"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Imagens filtradas existem
>>> assert 'imagens_brilhantes' in dir(), "Variável imagens_brilhantes não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 7: Imagens filtradas são numpy array
>>> import numpy as np
>>> assert isinstance(imagens_brilhantes, np.ndarray), "imagens_brilhantes deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 8: Número correto de imagens
>>> assert imagens_brilhantes.shape[0] == mascara_brilhantes.sum(), "Número de imagens deve corresponder ao número de True na máscara"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 9: Shape individual correto
>>> assert imagens_brilhantes.shape[1:] == (8, 8), "Cada imagem deve ter shape (8, 8)"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# %%writefile tests/ex5b.py
OK_FORMAT = True

test = {
    "name": "ex5b",
    "points": 4,
    "suites": [
        {
            "cases": [
                {
                    "code": r"""
>>> # Teste 1: Variável existe
>>> assert 'meses_bons' in dir(), "Variável meses_bons não foi criada"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 2: É numpy array
>>> import numpy as np
>>> assert isinstance(meses_bons, np.ndarray), "meses_bons deve ser um numpy array"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 3: É array 1D
>>> assert len(meses_bons.shape) == 1, "meses_bons deve ser um array 1D"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 4: Meses corretos
>>> import numpy as np
>>> mascara_teste = vendas_por_mes > 8000
>>> indices_esperados = np.where(mascara_teste)[0] + 1
>>> assert np.array_equal(meses_bons, indices_esperados), "Meses incorretos. Use np.where() e some 1"
>>> True
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 5: Meses no intervalo válido (início)
>>> len(meses_bons) == 0 or meses_bons.min() >= 1
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 6: Meses no intervalo válido (fim)
>>> len(meses_bons) == 0 or meses_bons.max() <= 12
True
""",
                    "hidden": False,
                    "locked": False
                },
                {
                    "code": r"""
>>> # Teste 7: Todos os meses atendem ao critério
>>> all(vendas_por_mes[mes-1] > 8000 for mes in meses_bons)
True
""",
                    "hidden": False,
                    "locked": False
                }
            ],
            "scored": True,
            "setup": "",
            "teardown": "",
            "type": "doctest"
        }
    ]
}

# %%
# Imports necessários
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# Configurações
np.random.seed(42)
np.set_printoptions(precision=2, suppress=True)
plt.rcParams['figure.figsize'] = (10, 6)

print("Setup completo!")

# %% [markdown]
# ## Exercício 1: Manipulação Básica de Tensores 3D
#
# Neste exercício você praticará operações fundamentais com tensores 3D.

# %% [markdown]
# ### Parte A
#
# Crie um tensor 3D chamado `tensor_3d` com shape (4, 5, 6) contendo números inteiros aleatórios entre 10 e 50 (inclusive).
#
# Use `np.random.seed(42)` antes de gerar o tensor.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'tensor_3d' in dir(), "Variável tensor_3d não foi criada"
# TEST
assert isinstance(tensor_3d, np.ndarray), "tensor_3d deve ser um numpy array"
# TEST
assert tensor_3d.shape == (4, 5, 6), f"Shape incorreto: esperado (4, 5, 6), obtido {tensor_3d.shape}"
# TEST
assert tensor_3d.min() >= 10, f"Valor mínimo deve ser >= 10, obtido {tensor_3d.min()}"
# TEST
assert tensor_3d.max() <= 50, f"Valor máximo deve ser <= 50, obtido {tensor_3d.max()}"
# TEST
assert tensor_3d.dtype in [np.int32, np.int64], "tensor_3d deve conter inteiros"
# TEST
np.random.seed(42)
expected = np.random.randint(10, 51, size=(4, 5, 6))
assert np.array_equal(tensor_3d, expected), "Valores incorretos. Certifique-se de usar np.random.seed(42) antes de gerar o tensor"
# END TESTS

# %%
# Verificar Exercício 1A
grader.check("ex1a")

# %% [markdown]
# ### Parte B
#
# Extraia a **segunda camada** (índice 1 na primeira dimensão) do `tensor_3d` e armazene em uma variável chamada `camada_2`.
#
# A camada deve ter shape (5, 6).

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'camada_2' in dir(), "Variável camada_2 não foi criada"
# TEST
assert isinstance(camada_2, np.ndarray), "camada_2 deve ser um numpy array"
# TEST
assert camada_2.shape == (5, 6), f"Shape incorreto: esperado (5, 6), obtido {camada_2.shape}"
# TEST
assert np.array_equal(camada_2, tensor_3d[1]), "camada_2 deve ser igual a tensor_3d[1]"
# END TESTS

# %%
# Verificar Exercício 1B
grader.check("ex1b")

# %% [markdown]
# ### Parte C
#
# Calcule a **média ao longo da primeira dimensão** (axis=0) do `tensor_3d` e armazene em `media_axis0`.
#
# O resultado deve ter shape (5, 6).

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'media_axis0' in dir(), "Variável media_axis0 não foi criada"
# TEST
assert isinstance(media_axis0, np.ndarray), "media_axis0 deve ser um numpy array"
# TEST
assert media_axis0.shape == (5, 6), f"Shape incorreto: esperado (5, 6), obtido {media_axis0.shape}"
# TEST
expected_mean = tensor_3d.mean(axis=0)
assert np.allclose(media_axis0, expected_mean), "Valores incorretos. Use .mean(axis=0)"
# TEST
assert np.isclose(media_axis0.mean(), tensor_3d.mean()), "A média global deve ser preservada"
# END TESTS

# %%
# Verificar Exercício 1C
grader.check("ex1c")

# %% [markdown]
# ## Exercício 2: Análise de Imagens MNIST
#
# Trabalharemos com o dataset MNIST para praticar análise de dados multidimensionais.
#
# Execute a célula abaixo para carregar os dados:

# %%
# Carregar MNIST
digits = load_digits()
X = digits.images  # (1797, 8, 8)
y = digits.target  # (1797,)

print(f"Shape das imagens: {X.shape}")
print(f"Shape dos labels: {y.shape}")

# %% [markdown]
# ### Parte A
#
# Calcule a **intensidade média de cada imagem** (média dos 64 pixels) e armazene em um array chamado `intensidade_media`.
#
# O array deve ter shape (1797,) e cada elemento representa a média dos pixels de uma imagem.
#
# **Dica:** Use `axis=(1, 2)` para agregar as dimensões espaciais.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'intensidade_media' in dir(), "Variável intensidade_media não foi criada"
# TEST
assert isinstance(intensidade_media, np.ndarray), "intensidade_media deve ser um numpy array"
# TEST
assert intensidade_media.shape == (1797,), f"Shape incorreto: esperado (1797,), obtido {intensidade_media.shape}"
# TEST
expected_intensidade = X.mean(axis=(1, 2))
assert np.allclose(intensidade_media, expected_intensidade), "Valores incorretos. Use .mean(axis=(1, 2))"
# TEST
assert intensidade_media.min() >= 0, "Intensidades não podem ser negativas"
# TEST
assert intensidade_media.max() <= 16, "Intensidades não podem exceder o máximo do dataset"
# TEST
assert np.isclose(intensidade_media.mean(), X.mean()), "A média global deve ser preservada"
# END TESTS

# %%
# Verificar Exercício 2A
grader.check("ex2a")

# %% [markdown]
# ### Parte B
#
# Calcule a **imagem média** para cada dígito (0-9).
#
# Crie um array chamado `imagens_medias` com shape (10, 8, 8), onde:
# - `imagens_medias[0]` é a média de todas as imagens do dígito 0
# - `imagens_medias[1]` é a média de todas as imagens do dígito 1
# - etc.
#
# **Dica:** Use um loop for de 0 a 9, e para cada dígito:
# 1. Crie uma máscara booleana (`y == digito`)
# 2. Selecione as imagens desse dígito
# 3. Calcule a média ao longo do axis=0

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'imagens_medias' in dir(), "Variável imagens_medias não foi criada"
# TEST
assert isinstance(imagens_medias, np.ndarray), "imagens_medias deve ser um numpy array"
# TEST
assert imagens_medias.shape == (10, 8, 8), f"Shape incorreto: esperado (10, 8, 8), obtido {imagens_medias.shape}"
# TEST
for digito in range(10):
    expected = X[y == digito].mean(axis=0)
    assert np.allclose(imagens_medias[digito], expected), f"Imagem média incorreta para dígito {digito}"
# TEST
assert imagens_medias.min() >= 0, "Valores não podem ser negativos"
# TEST
assert imagens_medias.max() <= 16, "Valores não podem exceder o máximo do dataset"
# END TESTS

# %%
# Verificar Exercício 2B
grader.check("ex2b")

# %% [markdown]
# ### Parte C
#
# Normalize as imagens do MNIST para o intervalo [0, 1].
#
# Crie um array chamado `X_normalizado` usando a fórmula:
#
# ```
# X_normalizado = (X - X.min()) / (X.max() - X.min())
# ```
#
# O array resultante deve ter:
# - Mesmo shape que X: (1797, 8, 8)
# - Valores entre 0 e 1

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'X_normalizado' in dir(), "Variável X_normalizado não foi criada"
# TEST
assert isinstance(X_normalizado, np.ndarray), "X_normalizado deve ser um numpy array"
# TEST
assert X_normalizado.shape == X.shape, f"Shape incorreto: esperado {X.shape}, obtido {X_normalizado.shape}"
# TEST
assert np.isclose(X_normalizado.min(), 0.0), f"Mínimo deve ser 0, obtido {X_normalizado.min()}"
# TEST
assert np.isclose(X_normalizado.max(), 1.0), f"Máximo deve ser 1, obtido {X_normalizado.max()}"
# TEST
expected = (X - X.min()) / (X.max() - X.min())
assert np.allclose(X_normalizado, expected), "Fórmula de normalização incorreta"
# END TESTS

# %%
# Verificar Exercício 2C
grader.check("ex2c")

# %% [markdown]
# ## Exercício 3: Análise de Dados de Vendas 3D
#
# Trabalharemos com dados sintéticos de vendas em 3 dimensões: produtos × regiões × meses.
#
# Execute a célula abaixo para criar os dados:

# %%
# Criar dados sintéticos de vendas
np.random.seed(42)
n_produtos = 5
n_regioes = 3
n_meses = 12

vendas = np.random.randint(100, 500, size=(n_produtos, n_regioes, n_meses))

print(f"Shape dos dados de vendas: {vendas.shape}")
print(f"Interpretação: (5 produtos, 3 regiões, 12 meses)")

# %% [markdown]
# ### Parte A
#
# Calcule o **total de vendas por produto** (somando todas as regiões e todos os meses).
#
# Crie um array chamado `vendas_por_produto` com shape (5,).
#
# **Dica:** Use `.sum()` com `axis=(1, 2)`.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'vendas_por_produto' in dir(), "Variável vendas_por_produto não foi criada"
# TEST
assert isinstance(vendas_por_produto, np.ndarray), "vendas_por_produto deve ser um numpy array"
# TEST
assert vendas_por_produto.shape == (5,), f"Shape incorreto: esperado (5,), obtido {vendas_por_produto.shape}"
# TEST
expected = vendas.sum(axis=(1, 2))
assert np.array_equal(vendas_por_produto, expected), "Valores incorretos. Use .sum(axis=(1, 2))"
# TEST
assert vendas_por_produto.sum() == vendas.sum(), "A soma total deve ser preservada"
# END TESTS

# %%
# Verificar Exercício 3A
grader.check("ex3a")

# %% [markdown]
# ### Parte B
#
# Calcule o **total de vendas por região** (somando todos os produtos e todos os meses).
#
# Crie um array chamado `vendas_por_regiao` com shape (3,).
#
# **Dica:** Use `.sum()` com `axis=(0, 2)`.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'vendas_por_regiao' in dir(), "Variável vendas_por_regiao não foi criada"
# TEST
assert isinstance(vendas_por_regiao, np.ndarray), "vendas_por_regiao deve ser um numpy array"
# TEST
assert vendas_por_regiao.shape == (3,), f"Shape incorreto: esperado (3,), obtido {vendas_por_regiao.shape}"
# TEST
expected = vendas.sum(axis=(0, 2))
assert np.array_equal(vendas_por_regiao, expected), "Valores incorretos. Use .sum(axis=(0, 2))"
# END TESTS

# %%
# Verificar Exercício 3B
grader.check("ex3b")

# %% [markdown]
# ### Parte C
#
# Calcule o **total de vendas por mês** (somando todos os produtos e todas as regiões).
#
# Crie um array chamado `vendas_por_mes` com shape (12,).
#
# **Dica:** Use `.sum()` com `axis=(0, 1)`.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'vendas_por_mes' in dir(), "Variável vendas_por_mes não foi criada"
# TEST
assert isinstance(vendas_por_mes, np.ndarray), "vendas_por_mes deve ser um numpy array"
# TEST
assert vendas_por_mes.shape == (12,), f"Shape incorreto: esperado (12,), obtido {vendas_por_mes.shape}"
# TEST
expected = vendas.sum(axis=(0, 1))
assert np.array_equal(vendas_por_mes, expected), "Valores incorretos. Use .sum(axis=(0, 1))"
# TEST
assert vendas_por_mes.sum() == vendas.sum(), "A soma total deve ser preservada"
# END TESTS

# %%
# Verificar Exercício 3C
grader.check("ex3c")

# %% [markdown]
# ## Exercício 4: Broadcasting e Normalização
#
# Pratique broadcasting para normalizar dados multidimensionais.

# %% [markdown]
# ### Parte A
#
# Normalize cada imagem do MNIST **individualmente** subtraindo sua própria média.
#
# Crie um array chamado `X_centrado` onde cada imagem tem média zero.
#
# **Passos:**
# 1. Calcule a média de cada imagem: `medias = X.mean(axis=(1, 2), keepdims=True)`
# 2. Subtraia usando broadcasting: `X_centrado = X - medias`
#
# O resultado deve ter:
# - Shape (1797, 8, 8)
# - Cada imagem com média aproximadamente zero

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'X_centrado' in dir(), "Variável X_centrado não foi criada"
# TEST
assert isinstance(X_centrado, np.ndarray), "X_centrado deve ser um numpy array"
# TEST
assert X_centrado.shape == X.shape, f"Shape incorreto: esperado {X.shape}, obtido {X_centrado.shape}"
# TEST
medias_teste = X.mean(axis=(1, 2), keepdims=True)
expected = X - medias_teste
assert np.allclose(X_centrado, expected), "Valores incorretos. Use broadcasting com keepdims=True"
# TEST
medias_por_imagem = X_centrado.mean(axis=(1, 2))
assert np.allclose(medias_por_imagem, 0, atol=1e-10), "Cada imagem deve ter média próxima de zero"
# TEST
assert 'medias' in dir(), "Variável medias não foi criada"
# TEST
assert medias.shape == (1797, 1, 1), f"Shape de medias deve ser (1797, 1, 1), obtido {medias.shape}"
# END TESTS

# %%
# Verificar Exercício 4A
grader.check("ex4a")

# %% [markdown]
# ### Parte B
#
# Normalize os dados de vendas subtraindo a **média de cada produto**.
#
# Crie um array chamado `vendas_normalizadas` onde cada produto tem média zero (considerando todas as regiões e meses).
#
# **Passos:**
# 1. Calcule a média de cada produto: `medias_produto = vendas.mean(axis=(1, 2), keepdims=True)`
# 2. Subtraia usando broadcasting: `vendas_normalizadas = vendas - medias_produto`
#
# O resultado deve ter shape (5, 3, 12).

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'vendas_normalizadas' in dir(), "Variável vendas_normalizadas não foi criada"
# TEST
assert isinstance(vendas_normalizadas, np.ndarray), "vendas_normalizadas deve ser um numpy array"
# TEST
assert vendas_normalizadas.shape == vendas.shape, f"Shape incorreto: esperado {vendas.shape}, obtido {vendas_normalizadas.shape}"
# TEST
medias_teste = vendas.mean(axis=(1, 2), keepdims=True)
expected = vendas - medias_teste
assert np.allclose(vendas_normalizadas, expected), "Valores incorretos. Use broadcasting com keepdims=True"
# TEST
for produto in range(5):
    media_produto = vendas_normalizadas[produto].mean()
    assert np.isclose(media_produto, 0, atol=1e-10), f"Produto {produto} deve ter média próxima de zero"
# END TESTS

# %%
# Verificar Exercício 4B
grader.check("ex4b")

# %% [markdown]
# ## Exercício 5: Máscaras Booleanas e Filtragem
#
# Pratique o uso de máscaras booleanas para filtrar dados multidimensionais.

# %% [markdown]
# ### Parte A
#
# Identifique as imagens do MNIST que têm **intensidade média maior que 10**.
#
# Crie:
# 1. Uma máscara booleana chamada `mascara_brilhantes` com shape (1797,)
# 2. Um array chamado `imagens_brilhantes` contendo apenas as imagens que passam no filtro
#
# **Dica:** Use o array `intensidade_media` que você calculou no Exercício 2A.

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'mascara_brilhantes' in dir(), "Variável mascara_brilhantes não foi criada"
# TEST
assert isinstance(mascara_brilhantes, np.ndarray), "mascara_brilhantes deve ser um numpy array"
# TEST
assert mascara_brilhantes.shape == (1797,), f"Shape incorreto: esperado (1797,), obtido {mascara_brilhantes.shape}"
# TEST
assert mascara_brilhantes.dtype == bool, "mascara_brilhantes deve ser booleana"
# TEST
expected_mask = intensidade_media > 10
assert np.array_equal(mascara_brilhantes, expected_mask), "Máscara incorreta. Use intensidade_media > 10"
# TEST
assert 'imagens_brilhantes' in dir(), "Variável imagens_brilhantes não foi criada"
# TEST
assert isinstance(imagens_brilhantes, np.ndarray), "imagens_brilhantes deve ser um numpy array"
# TEST
assert imagens_brilhantes.shape[0] == mascara_brilhantes.sum(), "Número de imagens deve corresponder ao número de True na máscara"
# TEST
assert imagens_brilhantes.shape[1:] == (8, 8), "Cada imagem deve ter shape (8, 8)"
# END TESTS

# %%
# Verificar Exercício 5A
grader.check("ex5a")

# %% [markdown]
# ### Parte B
#
# Identifique os meses em que as **vendas totais foram maiores que 8000 unidades**.
#
# Crie:
# 1. Um array chamado `meses_bons` contendo os **números dos meses** (1-12) que atingiram essa meta
#
# **Passos:**
# 1. Use o array `vendas_por_mes` do Exercício 3C
# 2. Crie uma máscara: `vendas_por_mes > 8000`
# 3. Use `np.where()` para obter os índices dos meses que passam no filtro
# 4. Some 1 aos índices (para converter de 0-11 para 1-12)
#
# **Exemplo:** Se os meses 0, 5 e 11 passarem no filtro, `meses_bons` deve ser `[1, 6, 12]`

# %%
# SEU CODIGO AQUI

# %%
# BEGIN TESTS
# TEST
assert 'meses_bons' in dir(), "Variável meses_bons não foi criada"
# TEST
assert isinstance(meses_bons, np.ndarray), "meses_bons deve ser um numpy array"
# TEST
assert len(meses_bons.shape) == 1, "meses_bons deve ser um array 1D"
# TEST
mascara_teste = vendas_por_mes > 8000
indices_esperados = np.where(mascara_teste)[0] + 1
assert np.array_equal(meses_bons, indices_esperados), "Meses incorretos. Use np.where() e some 1"
# TEST
if len(meses_bons) > 0:
    assert meses_bons.min() >= 1, "Meses devem começar em 1"
    assert meses_bons.max() <= 12, "Meses devem terminar em 12"
# TEST
for mes in meses_bons:
    assert vendas_por_mes[mes-1] > 8000, f"Mês {mes} não atende ao critério"
# END TESTS

# %%
# Verificar Exercício 5B
grader.check("ex5b")

# %% [markdown]
# ## Submissão
#
# Certifique-se de:
# 1. Executar todas as células em ordem (Menu: Runtime > Run all)
# 2. Verificar que todos os testes passaram
# 3. Salvar o notebook
# 4. Fazer download (File > Download > Download .ipynb)
# 5. Enviar via Moodle
#
# **Prazo de entrega:** Conforme indicado no Moodle.
